# %% [markdown]
# ## Mount the following data lake storage gen2 containers
# 1. raw
# 2. processed
# 3. lookup

# %% [markdown]
# ### Set-up the configs
# #### Please update the following
# - application-id
# - service-credential
# - directory-id

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": "47846408-5bca-44f4-9de3-71fd3b08a9d6",
           "fs.azure.account.oauth2.client.secret": "rty8Q~FbCdPpT37mAtAnTCisANbkYi.XyOYTMasI",
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/8603b7a6-42b5-4a50-a399-b1332d779cb6/oauth2/token"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Mount the raw container
# #### Update the storage account name before executing

# %%
dbutils.fs.mount(
  source = "abfss://raw@covidreportingdl020.dfs.core.windows.net/",
  mount_point = "/mnt/covidreportingdl020/raw",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: True</div>

# %% [markdown]
# ### Mount the processed container
# #### Update the storage account name before executing

# %%
dbutils.fs.mount(
  source = "abfss://prosessed@covidreportingdl020.dfs.core.windows.net/",
  mount_point = "/mnt/covidreportingdl020/processed",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: True</div>

# %% [markdown]
# ### Mount the lookup container
# #### Update the storage account name before executing

# %%
dbutils.fs.mount(
  source = "abfss://lookup@covidreportingdl020.dfs.core.windows.net/",
  mount_point = "/mnt/covidreportingdl020/lookup",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: True</div>

# %%
dbutils.fs.ls("/mnt/covidreportingdl020/lookup")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [FileInfo(path=&#39;dbfs:/mnt/covidreportingdl020/lookup/dim_country/&#39;, name=&#39;dim_country/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/covidreportingdl020/lookup/dim_date/&#39;, name=&#39;dim_date/&#39;, size=0)]</div>
